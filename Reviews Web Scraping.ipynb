# %%
# !pip install selenium

# %%
#importing the required libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests as rq
import selenium
import pandas as pd
from selenium import webdriver
import time
import re

# %%
from selenium.common.exceptions import NoSuchElementException

# %%
#let connect with the driver
driver = webdriver.Chrome(r"C:\Users\Dell\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url="https://www.amazon.in/product-reviews/B08444SXZ6/ref=acr_dp_hist_5?ie=UTF8&filterByStar=five_star&reviewerType=all_reviews#reviews-filter-"

# %%
driver.get(url)

# %%
review=[]

# %%
UR=[]
for i in range(0,70):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
for url in UR: #loop for every review in the list
        driver.get(url)
        try:
            rev=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span") # locating the ratings
            review.append(rev.text)
        
        except NoSuchElementException as e:
            review.append('No review')

# %%
review
# Out:
# ['Best Product Thnx for Amazon.in',
#  'Very nice phone.Eye protection also there.Awesome looking.Delivered very quickly',
#  'Nice',
#  "It's worth for 9.5k. after exchange offer.light weight n thin.easy to use.mobile have fingerprint n facial recognition to unlock and lifespan of battery lasts long.ram n rom are good.worth buying it.camera quality is ok.",
#  'Its a really very amazing and a nicely working phone..the camera quality and battery is also very good🤩😊.liked the product very much',
#  'Nice mobile prices 12,450',
#  "Oppo always exports premium quality mobiles. Let there be no such features like other mobile but i phone also doesn't export such features at high price, then?\nI have attached some pictures also you can check them incase you wanna see the picture quality.\nHence you can buy this without any tension.\nAmazing mobile's camera and body quality and display is also good.\nGo for it I suggest. 😃",
#  'Fantastic',
# ...

# %%
ratings=[]

# %%
for url in UR: #loop for every review in the list
        driver.get(url)
        try:
            rating=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings.append(rating.get_attribute('title'))
        
        except NoSuchElementException as e:
            Ratings.append('No ratings')

# %%
ratings
# Out:
# ['5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
# ...

# %%
len(ratings)
# Out:
# 700

# %%
len(review)
# Out:
# 700

# %%
url1="https://www.amazon.in/product-reviews/B08444SXZ6/ref=acr_dp_hist_4?ie=UTF8&filterByStar=four_star&reviewerType=all_reviews#reviews-filter-bar"

# %%
driver.get(url1)

# %%
UR=[]
for i in range(0,40):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review1=[]

# %%
for url1 in UR: #loop for every review in the list
        driver.get(url1)
        try:
            rev1=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span") # locating the ratings
            review1.append(rev1.text)
        
        except NoSuchElementException as e:
            review1.append('No review')

# %%
review1
# Out:
# ['Nice phone value for money but in inbox there is no earphone and screen protector receive being a regular customer of Amazon i am unhappy there was clearly written that these items are included in inbox.',
#  'Better to value for money , quality is as per shown ..And fast delivered by amazon.',
#  'Nice mobile in this Price 👌👌👌👌..',
#  'Nice product...but there is no C pin charger thts only one prob in this product...',
#  "Good product but as compared to Mi note 8 its not Good . If you want to rought use for bussiness purchase.. Provessor is slow , not for gaming. But want you tube and surffing it's usefull. Another all thing is good .\n\nI don't have time for upload pics , but this review is enought.\n\nProduct is same as photos.",
# ...

# %%
ratings1=[]

# %%
for url1 in UR: #loop for every review in the list
        driver.get(url1)
        try:
            rating1=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings1.append(rating1.get_attribute('title'))
        
        except NoSuchElementException as e:
            ratings1.append('No ratings')

# %%
len(review)
# Out:
# 700

# %%
url2="https://www.amazon.in/product-reviews/B08444SXZ6/ref=acr_dp_hist_3?ie=UTF8&filterByStar=three_star&reviewerType=all_reviews#reviews-filter-bar"

# %%
driver.get(url2)

# %%
UR=[]
for i in range(0,22):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review2=[]

# %%
for url2 in UR: #loop for every review in the list
        driver.get(url2)
        try:
            rev2=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span") # locating the ratings
            review2.append(rev2.text)
        
        except NoSuchElementException as e:
            review2.append('No review')

# %%
review2
# Out:
# ['i have recently bought this phone..on 18 may 2020.. delivery is good but there was no headphones in a box.features r awesome nd phone is working gud.but camera quality is bit bad.',
#  'I like the product. But as compared to my other phone Realme X2. I found the lag in processing in some of minor things also. It is having 6GB RAM then also the having some processing issue. I don;t like the product. Even after this specs, the things are getting lag.',
#  'Headsets are missing in the phone box...where are the original headsets...its normally included in phonebox??',
# ...

# %%
ratings2=[]

# %%
for url2 in UR: #loop for every review in the list
        driver.get(url2)
        try:
            rating2=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings2.append(rating2.get_attribute('title'))
        
        except NoSuchElementException as e:
            ratings2.append('No ratings')

# %%
ratings2
# Out:
# ['3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
# ...

# %%
url3="https://www.amazon.in/product-reviews/B08444SXZ6/ref=cm_cr_unknown?ie=UTF8&filterByStar=two_star&reviewerType=all_reviews&pageNumber=1#reviews-filter-bar"

# %%
driver.get(url3)

# %%
UR=[]
for i in range(0,12):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review3=[]

# %%
for url3 in UR: #loop for every review in the list
        driver.get(url3)
        try:
            rev3=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span") # locating the ratings
            review3.append(rev3.text)
        
        except NoSuchElementException as e:
            review3.append('No review')

# %%
review3
# Out:
# ["It's an average phone. Quite on the pretty side. ONLY those who are looking for a budget phone can think of purchasing this one. The camera is very average, but the functions & controls of the phone are smooth. It's very lightweight - that's a plus!",
#  'This product details said there is a earphone and screen protector. But i didnt get that',
#  'We have bought it 30 days back. Now we are getting problem in device keypad. Getting Hang on regular basis. Rest all things are as per our expectations. Now my request to Amazone please provide information to whom we can contact now !!',
#  "Horrible touch quality.\nBattery not good for 4250mah, it's more like 3000 mah.\nNot worth it!!! please get mi or samsung m series.\nThey r much better in touch , quality and durability.\nOnly thing positive is the looks.**\nThe touch is funny, doesn't always work smoothly.\nAnd the fone lags a lot.\nThe new phone feels like second hand.",
# ...

# %%
ratings3=[]

# %%
for url3 in UR: #loop for every review in the list
        driver.get(url3)
        try:
            rating3=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings3.append(rating3.get_attribute('title'))
        
        except NoSuchElementException as e:
            ratings3.append('No ratings')

# %%
ratings3
# Out:
# ['2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '2.0 out of 5 stars',
# ...

# %%
url4="https://www.amazon.in/product-reviews/B08444SXZ6/ref=cm_cr_unknown?ie=UTF8&filterByStar=one_star&reviewerType=all_reviews&pageNumber=1#reviews-filter-bar"

# %%
driver.get(url4)

# %%
UR=[]
for i in range(0,20):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review4=[]

# %%
for url4 in UR: #loop for every review in the list
        driver.get(url4)
        try:
            rev4=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span") # locating the ratings
            review4.append(rev4.text)
        
        except NoSuchElementException as e:
            review4.append('No review')

# %%
review4
# Out:
# ['I am not happy buy the mobile in amazon.\nWhats in the box:- Handset, Earphone, USB Cable, Sim Tray Ejecter, Pre-applied Screen Protector and Protective Case, Booklet with Warranty Card and Quick Guide',
#  "Please don't buy this mobile. Waste of money. I buy this mobile before 20 days only. Now not working properly. Hanging problem, handset very slow. Please don't buy it",
#  'Hi i received this item on 16 july.after 10 days phone start hanging.it automatically switched off.it repeating again and again.its being automatically switched of.please solve my issue.please take necessary action as soon as possible.',
#  'There is no headphone in the box... unsatisfied 😟 disappointed ☹️',
#  'when i ordered this phone , headphone is free with phone but received order without headphone',
# ...

# %%
ratings4=[]

# %%
for url4 in UR: #loop for every review in the list
        driver.get(url4)
        try:
            rating4=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings4.append(rating4.get_attribute('title'))
        
        except NoSuchElementException as e:
            ratings4.append('No ratings')

# %%
ratings4
# Out:
# ['1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
# ...

# %%
url5="https://www.amazon.in/product-reviews/B07HGGYWL6/ref=acr_dp_hist_5?ie=UTF8&filterByStar=five_star&reviewerType=all_reviews#reviews-filter-bar"

# %%
driver.get(url5)

# %%
UR=[]
for i in range(0,100):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review5=[]

# %%
for url5 in UR: #loop for every review in the list
        driver.get(url5)
        try:
            rev5=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span[1]") # locating the ratings
            review5.append(rev5.text)
        
        except NoSuchElementException as e:
            review5.append('No review')

# %%
review5
# Out:
# ["This is best thing you can get at this price from a reputed brand with Made in India tag. First time I ordered on the first day of online launch and am happy. I'm writing after few days of usage, but this should not be different as my experience with Samsung has been most consistent as compared to other mobile brands I've used earlier.\n\nGood:\n\n- Android 10! Beautiful looks! Finally I can delete SMS from notification now!!\n- Display is excellent with Blue light filter.\n- Performance is good. No heating or lagging. Real Racing worked fine.\n- 6000 Mah battery is BIG\n- 128 GB storage is pretty good. 512 GB card supported with dedicated external card slot.\n- Both dedicated sim slots support LTE\n- Fast charging and 15W charger top with phone. The phone came with 0% charge. Charged fast.\n- Mobile speakers sound is good, but I prefer external speakers for better bass in music.\n- Camera is really good. Macro performance is very good - look at skin in tatoo photo and dust perticl
# ...

# %%
ratings5=[]

# %%
len(ratings5)
# Out:
# 1000

# %%
for url5 in UR: #loop for every review in the list
        driver.get(url5)
        try:
            rating5=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings5.append(rating5.get_attribute('title'))
        
        except NoSuchElementException as e:
            ratings5.append('No ratings')

# %%
url6="https://www.amazon.in/product-reviews/B07HGGYWL6/ref=cm_cr_unknown?ie=UTF8&filterByStar=four_star&reviewerType=all_reviews&pageNumber=1#reviews-filter-bar"

# %%
driver.get(url6)

# %%
UR=[]
for i in range(0,100):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review6=[]

# %%
for url6 in UR: #loop for every review in the list
        driver.get(url6)
        try:
            rev6=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span[1]") # locating the ratings
            review6.append(rev6.text)
        
        except NoSuchElementException as e:
            review6.append('No review')

# %%
ratings6=[]

# %%
for url6 in UR: #loop for every review in the list
        driver.get(url6)
        try:
            rating6=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings6.append(rating6.get_attribute('title'))
        
        except NoSuchElementException as e:
            ratings6.append('No ratings')

# %%
url7="https://www.amazon.in/product-reviews/B07HGGYWL6/ref=cm_cr_unknown?ie=UTF8&filterByStar=three_star&reviewerType=all_reviews&pageNumber=1#reviews-filter-bar"

# %%
driver.get(url7)

# %%
UR=[]
for i in range(0,100):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review7=[]

# %%
for url7 in UR: #loop for every review in the list
        driver.get(url7)
        try:
            rev7=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span[1]") # locating the ratings
            review7.append(rev7.text)
        
        except NoSuchElementException as e:
            review7.append('No review')

# %%
ratings7=[]

# %%
for url7 in UR: #loop for every review in the list
        driver.get(url7)
        try:
            rating7=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings7.append(rating7.get_attribute('title'))
        
        except NoSuchElementException as e:
            ratings7.append('No ratings')

# %%
url8="https://www.amazon.in/product-reviews/B07HGGYWL6/ref=cm_cr_unknown?ie=UTF8&filterByStar=two_star&reviewerType=all_reviews&pageNumber=1#reviews-filter-bar"

# %%
driver.get(url8)

# %%
UR=[]
for i in range(0,80):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review8=[]

# %%
for url8 in UR: #loop for every review in the list
        driver.get(url8)
        try:
            rev8=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span[1]") # locating the ratings
            review8.append(rev8.text)
        
        except NoSuchElementException as e:
            review8.append('No review')

# %%
ratings8=[]

# %%
for url8 in UR: #loop for every review in the list
        driver.get(url8)
        try:
            rating8=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings8.append(rating8.get_attribute('title'))
        
        except NoSuchElementException as e:
            ratings8.append('No ratings')

# %%
url9="https://www.amazon.in/product-reviews/B07HGGYWL6/ref=cm_cr_unknown?ie=UTF8&filterByStar=one_star&reviewerType=all_reviews&pageNumber=1#reviews-filter-bar"

# %%
driver.get(url9)

# %%
UR=[]
for i in range(0,100):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review9=[]

# %%
for url9 in UR: #loop for every review in the list
        driver.get(url9)
        try:
            rev9=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span[1]") # locating the ratings
            review9.append(rev9.text)
        
        except NoSuchElementException as e:
            review9.append('No review')

# %%
ratings9=[]

# %%
for url9 in UR: #loop for every review in the list
        driver.get(url9)
        try:
            rating9=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings9.append(rating9.get_attribute('title'))
        
        except NoSuchElementException as e:
            ratings9.append('No ratings')

# %%
final_rev = review+review1+review2+review3+review4+review5+review6+review7+review8+review9

# %%
len(final_rev)
# Out:
# 6440

# %%
final_rat = ratings+ratings1+ratings2+ratings3+ratings4+ratings5+ratings6+ratings7+ratings8+ratings9

# %%
len(final_rat)
# Out:
# 6440

# %%
len(ratings5)
# Out:
# 2000

# %%
    df=pd.DataFrame({'Review':final_rev,
                     'Ratings':final_rat
                     })

# %%
print(df)
# Out:
#                                                  Review             Ratings
# 0                       Best Product Thnx for Amazon.in  5.0 out of 5 stars
# 1     Very nice phone.Eye protection also there.Awes...  5.0 out of 5 stars
# 2                                                  Nice  5.0 out of 5 stars
# 3     It's worth for 9.5k. after exchange offer.ligh...  5.0 out of 5 stars
# 4     Its a really very amazing and a nicely working...  5.0 out of 5 stars
# ...                                                 ...                 ...
# 6435  Mobile screen color fade away, within 15days o...  1.0 out of 5 stars
# 6436  This Phn is totally waste of money and facing ...  1.0 out of 5 stars
# 6437  Camera is falthu, I am a samsung lover... but ...  1.0 out of 5 stars
# 6438  Don't go for this it bought this on 1st july g...  1.0 out of 5 stars
# 6439  Only good thing in this phone is it's battery ...  1.0 out of 5 stars
#
# [6440 rows x 2 columns]

# %%
df.to_excel('Ratings_prediction.xlsx', index = False)

# %%
len(final_rat)
# Out:
# 7440

# %%
#headphones

# %%
url="https://www.amazon.in/product-reviews/B086CSGV2N/ref=cm_cr_unknown?ie=UTF8&filterByStar=five_star&reviewerType=all_reviews&pageNumber=1#reviews-filter-bar"

# %%
driver.get(url)

# %%
UR=[]
for i in range(0,70):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review=[]

# %%
for url in UR: #loop for every review in the list
        driver.get(url)
        try:
            rev=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span[1]") # locating the ratings
            review.append(rev.text)
        
        except NoSuchElementException as e:
            review.append('No review')

# %%
ratings=[]

# %%
len(review)
# Out:
# 700

# %%
ratings
# Out:
# ['5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
# ...

# %%
for url in UR: #loop for every review in the list
        driver.get(url)
        try:
            rating=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings.append(rating.get_attribute('title'))
        
        except NoSuchElementException as e:
            Ratings.append('No ratings')

# %%
url1="https://www.amazon.in/product-reviews/B086CSGV2N/ref=cm_cr_unknown?ie=UTF8&filterByStar=four_star&reviewerType=all_reviews&pageNumber=1#reviews-filter-bar"

# %%
driver.get(url1)

# %%
UR=[]
for i in range(0,70):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review1=[]

# %%
for url1 in UR: #loop for every review in the list
        driver.get(url1)
        try:
            rev1=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span") # locating the ratings
            review1.append(rev1.text)
        
        except NoSuchElementException as e:
            review1.append('No review')

# %%
ratings1=[]

# %%
for url1 in UR: #loop for every review in the list
        driver.get(url1)
        try:
            rating1=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings1.append(rating1.get_attribute('title'))
        
        except NoSuchElementException as e:
            ratings1.append('No ratings')

# %%
url2="https://www.amazon.in/product-reviews/B086CSGV2N/ref=cm_cr_unknown?ie=UTF8&filterByStar=three_star&reviewerType=all_reviews&pageNumber=1#reviews-filter-bar"

# %%
driver.get(url2)

# %%
UR=[]
for i in range(0,70):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review2=[]

# %%
for url2 in UR: #loop for every review in the list
        driver.get(url2)
        try:
            rev2=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span") # locating the ratings
            review2.append(rev2.text)
        
        except NoSuchElementException as e:
            review2.append('No review')

# %%
ratings2=[]

# %%
for url2 in UR: #loop for every review in the list
        driver.get(url2)
        try:
            rating2=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings2.append(rating2.get_attribute('title'))
        
        except NoSuchElementException as e:
            ratings2.append('No ratings')

# %%
url3="https://www.amazon.in/product-reviews/B086CSGV2N/ref=cm_cr_unknown?ie=UTF8&filterByStar=two_star&reviewerType=all_reviews&pageNumber=1#reviews-filter-bar"

# %%
driver.get(url3)

# %%
UR=[]
for i in range(0,70):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review3=[]

# %%
for url3 in UR: #loop for every review in the list
        driver.get(url3)
        try:
            rev3=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span") # locating the ratings
            review3.append(rev3.text)
        
        except NoSuchElementException as e:
            review3.append('No review')

# %%
ratings3=[]

# %%
for url3 in UR: #loop for every review in the list
        driver.get(url3)
        try:
            rating3=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings3.append(rating3.get_attribute('title'))
        
        except NoSuchElementException as e:
            ratings3.append('No ratings')

# %%
url4="https://www.amazon.in/product-reviews/B086CSGV2N/ref=cm_cr_unknown?ie=UTF8&filterByStar=one_star&reviewerType=all_reviews&pageNumber=1#reviews-filter-bar"

# %%
driver.get(url4)

# %%
UR=[]
for i in range(0,90):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review4=[]

# %%
for url4 in UR: #loop for every review in the list
        driver.get(url4)
        try:
            rev4=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span") # locating the ratings
            review4.append(rev4.text)
        
        except NoSuchElementException as e:
            review4.append('No review')

# %%
ratings4=[]

# %%
for url4 in UR: #loop for every review in the list
        driver.get(url4)
        try:
            rating4=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings4.append(rating4.get_attribute('title'))
        
        except NoSuchElementException as e:
            ratings4.append('No ratings')

# %%
len(review4)
# Out:
# 900

# %%
len(ratings4)
# Out:
# 900

# %%
final_rev = review+review1+review2+review3+review4

# %%
final_rat = ratings+ratings1+ratings2+ratings3+ratings4

# %%
len(final_rev)
# Out:
# 3700

# %%
len(final_rat)
# Out:
# 3700

# %%
df=pd.DataFrame({'Review':final_rev,
                     'Ratings':final_rat
                     })

# %%
print(df)
# Out:
#                                                  Review             Ratings
# 0     Recieved today\nWorth for 2k\nBut I had one pl...  5.0 out of 5 stars
# 1     Product is just amazing!!\nWith the reasonable...  5.0 out of 5 stars
# 2                   Product price is low as we expected  5.0 out of 5 stars
# 3                              It's very nice neckband.  5.0 out of 5 stars
# 4     Excellent product,\n\nAfter using for 2 hrs st...  5.0 out of 5 stars
# ...                                                 ...                 ...
# 3695  Stopped functioning after 6 months of use. Not...  1.0 out of 5 stars
# 3696  I bought the product 2 months ago .. but now I...  1.0 out of 5 stars
# 3697  I received One plus wireless blue tooth z on y...  1.0 out of 5 stars
# 3698  It was didnt cancell around noise it cancell o...  1.0 out of 5 stars
# 3699  Very bad quality.. if someone is travelling an...  1.0 out of 5 stars
#
# [3700 rows x 2 columns]

# %%
df.to_excel('Ratings_prediction1.xlsx', index = False)

# %%
url="https://www.flipkart.com/redmi-9i-midnight-black-64-gb/product-reviews/itm0e1018dac2627?pid=MOBFV8RYKWQ3HACE&lid=LSTMOBFV8RYKWQ3HACEV2QOWQ&marketplace=FLIPKART"

# %%
comment=[]
ratings=[]

# %%
i=1
while i<=170:
    ss=driver.get(str(url)+"&page="+str(i))
    qq=driver.current_url
    r2=rq.get(qq)
    soup=BeautifulSoup(r2.text,'html.parser')
    try:
        for ra in soup.find_all('div',{'class':'t-ZTKy'}):
            cc=ra.get_text()
            comment.append(cc)
        for rr in soup.find_all('div',{'class':'_3LWZlK _1BLPMq'}):
            ce=rr.get_text()
            ratings.append(ce)
    except NoSuchElementException as e:
        comment.append('No review')
    
        sleep(1)
    i+=1

# %%
comment = comment[:1100]

# %%
ratings = ratings[:1100]

# %%
# Out:
# 1100

# %%
url1 = "https://www.flipkart.com/canon-eos-3000d-dslr-camera-1-body-18-55-mm-lens/product-reviews/itm6f665fea97bc2?pid=CAMF3DHJURPEMNRN&lid=LSTCAMF3DHJURPEMNRNYD4BKP&marketplace=FLIPKART"

# %%
comment1=[]
ratings1=[]

# %%
i=1
while i<=300:
    ss=driver.get(str(url1)+"&page="+str(i))
    qq=driver.current_url
    r2=rq.get(qq)
    soup=BeautifulSoup(r2.text,'html.parser')
    try:
        for ra in soup.find_all('div',{'class':'t-ZTKy'}):
            cc=ra.get_text()
            comment1.append(cc)
        for rr in soup.find_all('div',{'class':'_3LWZlK _1BLPMq'}):
            ce=rr.get_text()
            ratings1.append(ce)
    except NoSuchElementException as e:
        comment1.append('No review')
    
        sleep(1)
    i+=1

# %%
comment1=comment1[0:2700]
ratings1=ratings1[0:2700]

# %%
comment1
# Out:
# ["product really great . I am totally sctified this product .really good camera for beggner .but flash button was missing that is not good .and capture is 18 mp wasn't good I was hopeed it will be 24 mp . it is also missing .n everything is good .READ MORE",
#  'Satisfied with the product.. Its a really good for all who wants to learn photography its a gem and love.... Go for itt....10/10READ MORE',
#  'The camera simply awesome..and it is a best budget DSLR and begginer DSLR for first time user...auto focus mode works good in daylightREAD MORE',
#  'Worth more than the amount. Best DSLR for a good beginner. Friendly camera. Love it. ❤️ Extremely good with canon 50mm f1.8 STM lens.READ MORE',
#  'product is very good and build quality also , special thanks to Flipkart for fast delivery , best camera for starters , it captures best quality photosREAD MORE',
# ...

# %%
url2 = "https://www.flipkart.com/oneplus-bullets-wireless-z-bass-bluetooth-headset/product-reviews/itme024ffec952c5?pid=ACCG2K38YCACC3XV&lid=LSTACCG2K38YCACC3XVJYX6YF&marketplace=FLIPKART"

# %%
comment2=[]
ratings2=[]

# %%
i=1
while i<=700:
    ss=driver.get(str(url1)+"&page="+str(i))
    qq=driver.current_url
    r2=rq.get(qq)
    soup=BeautifulSoup(r2.text,'html.parser')
    try:
        for ra in soup.find_all('div',{'class':'t-ZTKy'}):
            cc=ra.get_text()
            comment2.append(cc)
        for rr in soup.find_all('div',{'class':'_3LWZlK _1BLPMq'}):
            ce=rr.get_text()
            ratings2.append(ce)
    except NoSuchElementException as e:
        comment1.append('No review')
        ratings2.append('1')
    
        sleep(1)
    i+=1

# %%
comment2 = comment2[0:3000]
ratings2 = ratings2[0:3000]

# %%
review = comment+comment1+comment2
rating = ratings+ratings1+ratings2

# %%
df=pd.DataFrame({'Review':review,
                     'Ratings':rating
                     })

# %%
print(df)
# Out:
#                                                  Review Ratings
# 0     Thankyou Redmi,Feeling Lucky to buy this produ...       5
# 1     Good mobile ...I loved it and Thank you flipka...       4
# 2     It is an good phone ever i see, but it have on...       5
# 3     To be completely honest this is not the best p...       5
# 4     Nice very super product and nice performance B...       5
# ...                                                 ...     ...
# 6795                   best entry level cameraREAD MORE       5
# 6796  This was my first DSLR...n it's amazing....val...       5
# 6797                Best Camera in this budgetREAD MORE       5
# 6798  very basic model... put some more money. buy a...       5
# 6799                                Good one..READ MORE       5
#
# [6800 rows x 2 columns]

# %%
df.to_excel('Ratings_prediction2.xlsx', index = False)

# %%
url = "https://www.amazon.in/product-reviews/B08D9NDZ1Y/ref=acr_dp_hist_1?ie=UTF8&filterByStar=one_star&reviewerType=all_reviews#reviews-filter-bar"

# %%
driver.get(url)

# %%
UR=[]
for i in range(0,150):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review=[]

# %%
for url in UR: #loop for every review in the list
        driver.get(url)
        try:
            rev=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span") # locating the ratings
            review.append(rev.text)
        
        except NoSuchElementException as e:
            review.append('No review')

# %%
ratings=[]

# %%
for url in UR: #loop for every review in the list
        driver.get(url)
        try:
            rating=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings.append(rating.get_attribute('title'))
        
        except NoSuchElementException as e:
            ratings.append('No ratings')

# %%
df=pd.DataFrame({'Review':review,
                     'Ratings':ratings
                     })

# %%
print(df)
# Out:
#                                                  Review             Ratings
# 0     I won't recommend this. Hardly it worked, it's...  1.0 out of 5 stars
# 1     Printer catridge 805 not available anywhere in...  1.0 out of 5 stars
# 2     Waste of money. Because I had printed around 7...  1.0 out of 5 stars
# 3     A very bad product. I can't imagine HP is sell...  1.0 out of 5 stars
# 4     Worst printer. Just to check, gave a print for...  1.0 out of 5 stars
# ...                                                 ...                 ...
# 1495                                              Waste  1.0 out of 5 stars
# 1496                       i want to replace my product  1.0 out of 5 stars
# 1497                                           Not good  1.0 out of 5 stars
# 1498  more ink consumed which place cartridge purchased  1.0 out of 5 stars
# 1499                                       Doesn't work  1.0 out of 5 stars
#
# [1500 rows x 2 columns]

# %%
df.to_excel('Ratings_prediction3.xlsx', index = False)

# %%
url1 = "https://www.amazon.in/product-reviews/B084872DQY/ref=acr_dp_hist_1?ie=UTF8&filterByStar=one_star&reviewerType=all_reviews#reviews-filter-bar"

# %%
driver.get(url1)

# %%
UR=[]
for i in range(0,170):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review1=[]

# %%
for url1 in UR: #loop for every review in the list
        driver.get(url1)
        try:
            rev1=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span") # locating the ratings
            review1.append(rev1.text)
        
        except NoSuchElementException as e:
            review1.append('No review')

# %%
ratings1=[]

# %%
for url1 in UR: #loop for every review in the list
        driver.get(url1)
        try:
            rating1=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings1.append(rating1.get_attribute('title'))
        
        except NoSuchElementException as e:
            ratings1.append('No ratings')

# %%
url2 = "https://www.amazon.in/product-reviews/B084872DQY/ref=acr_dp_hist_2?ie=UTF8&filterByStar=two_star&reviewerType=all_reviews#reviews-filter-bar"

# %%
driver.get(url2)

# %%
UR=[]
for i in range(0,40):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review2=[]

# %%
for url2 in UR: #loop for every review in the list
        driver.get(url2)
        try:
            rev2=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span") # locating the ratings
            review2.append(rev2.text)
        
        except NoSuchElementException as e:
            review2.append('No review')

# %%
ratings2=[]

# %%
for url2 in UR: #loop for every review in the list
        driver.get(url2)
        try:
            rating2=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings2.append(rating2.get_attribute('title'))
        
        except NoSuchElementException as e:
            ratings2.append('No ratings')

# %%
url3= "https://www.amazon.in/product-reviews/B01HGCLUH6/ref=acr_dp_hist_2?ie=UTF8&filterByStar=two_star&reviewerType=all_reviews#reviews-filter-bar"

# %%
driver.get(url3)

# %%
UR=[]
for i in range(0,200):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review3=[]

# %%
for url3 in UR: #loop for every review in the list
        driver.get(url3)
        try:
            rev3=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span") # locating the ratings
            review3.append(rev3.text)
        
        except NoSuchElementException as e:
            review3.append('No review')

# %%
ratings3=[]

# %%
for url3 in UR: #loop for every review in the list
        driver.get(url3)
        try:
            rating3=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings3.append(rating3.get_attribute('title'))
        
        except NoSuchElementException as e:
            ratings3.append('No ratings')

# %%
url4 = "https://www.amazon.in/product-reviews/B01HGCLUH6/ref=cm_cr_unknown?ie=UTF8&filterByStar=three_star&reviewerType=all_reviews&pageNumber=1#reviews-filter-bar"

# %%
driver.get(url4)

# %%
UR=[]
for i in range(0,200):
    urls=driver.find_elements_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    for i in urls:
        UR.append(i.get_attribute('href'))# getting the urls
        
    time.sleep(3)
    
    url21=driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute("href")
    time.sleep(2)
    driver.get(url21)

# %%
review4=[]

# %%
for url4 in UR: #loop for every review in the list
        driver.get(url4)
        try:
            rev4=driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']/span") # locating the ratings
            review4.append(rev4.text)
        
        except NoSuchElementException as e:
            review4.append('No review')

# %%
ratings4=[]

# %%
for url4 in UR: #loop for every review in the list
        driver.get(url4)
        try:
            rating4=driver.find_element_by_xpath("//a[@class='a-link-normal']") # locating the ratings
            ratings4.append(rating4.get_attribute('title'))
        
        except NoSuchElementException as e:
            ratings4.append('No ratings')

# %%
review = review1+review2+review3+review4
ratings = ratings1+ratings2+ratings3+ratings4

# %%
df=pd.DataFrame({'Review':review,
                     'Ratings':ratings
                     })

# %%
print(df)
# Out:
#                                                  Review             Ratings
# 0     I bought this TV, As it is an android TV it sh...  1.0 out of 5 stars
# 1     The picture quality is not good. Resolution is...  1.0 out of 5 stars
# 2     I will suggest all who are buying this in the ...  1.0 out of 5 stars
# 3     Hi guys I have purchased MI TV in the month of...  1.0 out of 5 stars
# 4     I bought it in October. Got delivered fast, on...  1.0 out of 5 stars
# ...                                                 ...                 ...
# 4730                                            It's ok  3.0 out of 5 stars
# 4731  this is not great model to buy, instead prefer...  3.0 out of 5 stars
# 4732                      Product is not that much good  3.0 out of 5 stars
# 4733                                               Good  3.0 out of 5 stars
# 4734                 signal power degrades after 1 year  3.0 out of 5 stars
#
# [4735 rows x 2 columns]

# %%
df.to_excel('Ratings_prediction4.xlsx', index = False)
